# %% [markdown]
# <a href="https://colab.research.google.com/github/AshwinAbraham2021/WiDS-Training-AI-to-play-games-using-Reinforcement-Learning/blob/master/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Reinforcement Learning - changed in Colab by Prerak
